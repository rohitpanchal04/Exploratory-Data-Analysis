# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA) 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
bi=pd.read_csv('bikes.csv')

# %%
bi
# Out:
#            date  temperature   humidity  windspeed       count
# 0    2011-01-03     2.716070  45.715346  21.414957  120.000000
# 1    2011-01-04     2.896673  54.267219  15.136882  108.000000
# 2    2011-01-05     4.235654  45.697702  17.034578   82.000000
# 3    2011-01-06     3.112643  50.237349  10.091568   88.000000
# 4    2011-01-07     2.723918  49.144928  15.738204  148.000000
# ..          ...          ...        ...        ...         ...
# 186  2011-07-08    28.187490  63.618656  19.761499  692.000000
# 187  2011-07-09    29.070524  61.346450  21.121738  702.333333
# 188  2011-07-10    29.953558  59.074244  22.481976  712.666667
# 189  2011-07-11    30.836592  56.802038  23.842215  723.000000
# 190  2011-07-12    32.409522  52.521355  17.987135  662.000000
#
# [191 rows x 5 columns]

# %%
bi.shape
# Out:
# (191, 5)

# %%
bi.columns
# Out:
# Index(['date', 'temperature', 'humidity', 'windspeed', 'count'], dtype='object')

# %%
bi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         191 non-null    object
#  1   temperature  191 non-null    float64
#  2   humidity     191 non-null    float64
#  3   windspeed    191 non-null    float64
#  4   count        191 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.6+ KB

# %% [markdown]
# # SUMMARY STATISTICS

# %%
bk=bi.describe()

# %%
bk
# Out:
#        temperature    humidity   windspeed        count
# count   191.000000  191.000000  191.000000   191.000000
# mean     15.319033   55.469244   18.605591   461.976440
# std       9.876723    7.998748    5.049424   321.669925
# min      -2.200000   21.300000    6.941802     9.000000
# 25%       6.091402   49.593148   14.600733   144.000000
# 50%      15.769749   55.080463   18.474898   460.000000
# 75%      24.255189   62.046729   21.621460   740.333333
# max      33.113161   72.575560   33.512660  1246.000000

# %% [raw]
# Key Observation:
#     If your mean is greater than median so its mean those columns skewness is Positive.
#     So Skewness is present inside the dataset and Standard Deviation is too high
#     so spread of all the data are too high.
#
# Observation:
#     The mean is more than median(50th Percentile) but not too much more.
#     There is large difference in 75th Percentile and max in temperature and counts

# %%
bi.windspeed.unique()
# Out:
# array([21.41495651, 15.13688189, 17.03457765, 10.09156767, 15.73820407,
#        17.03502942, 18.33185477, 19.62868011, 12.41459723, 25.43218813,
#        25.1734698 , 12.7295959 , 13.09030004, 13.45100418, 13.81170833,
#        14.17241247, 18.56227838, 17.67684395, 28.89995536, 24.26551848,
#        19.6310816 , 14.99664471, 12.9612797 , 24.66345158, 11.82290476,
#        12.49791209, 14.01707685, 15.53624161, 17.05540637,  7.49852091,
#        22.55618469, 23.51516161, 12.8216845 , 10.86172372,  8.90176293,
#         6.94180215, 29.52110762, 17.17288889, 19.53366693, 11.44577661,
#        18.80140441, 26.1570322 , 33.51266   , 24.48683548, 21.66333182,
#        20.11637166, 22.60019605, 21.36541698, 20.1306379 , 18.89585883,
#        17.66107975, 10.41596779, 21.57095789, 28.4218222 , 27.07002426,
#        25.71822632, 24.36642838, 19.14063191, 25.66087602, 19.80608086,
#        18.20769089, 21.48906965, 24.77044841, 28.05182716, 12.30888436,
# ...

# %%
bi.temperature.unique()
# Out:
# array([ 2.71606966,  2.8966733 ,  4.23565354,  3.11264266,  2.72391768,
#         1.96744541,  1.21097315,  0.45450089,  1.36139339,  1.54199703,
#         1.15818947,  0.95304838,  1.64592111,  2.33879384,  3.03166657,
#         3.7245393 ,  7.47504496,  5.95973279,  1.77907655,  0.4527177 ,
#        -0.87364115, -2.2       ,  4.06284825,  3.76591521,  2.64831846,
#         3.06942892,  2.69449591,  2.31956289,  1.94462988,  2.50794831,
#         5.87693129,  2.24881488,  3.4581539 ,  4.45758342,  5.45701293,
#         6.45644245,  3.93146854, -0.34271812,  0.13238467,  2.35481272,
#         6.09518551,  9.8355583 , 13.57593109,  6.17927846,  8.77081146,
#        14.61072633, 18.87418407, 14.65904376, 10.44390346,  6.22876316,
#         2.01362286,  3.97647044,  7.64780058, 11.05999729, 11.77070604,
#        12.48141478, 13.19212353,  6.20808762,  9.60225377,  2.8138718 ,
#         5.96092489,  5.96211699,  5.9633091 ,  7.4912377 ,  7.65679103,
# ...

# %%
bi.temperature.value_counts()
# Out:
# temperature
# 24.503544    2
# 5.959733     2
# 13.534555    2
# 23.758479    2
# 13.575931    2
#             ..
# 5.963309     1
# 7.491238     1
# 7.656791     1
# 12.289006    1
# 32.409522    1
# Name: count, Length: 180, dtype: int64

# %%
bi.windspeed.value_counts()
# Out:
# windspeed
# 18.474898    2
# 14.394110    2
# 16.788770    1
# 28.145628    1
# 27.170459    1
#             ..
# 19.406341    1
# 22.382778    1
# 20.320807    1
# 18.037162    1
# 17.987135    1
# Name: count, Length: 189, dtype: int64

# %%
bi.humidity.value_counts()
# Out:
# humidity
# 54.964157    2
# 64.595777    2
# 46.821447    2
# 46.100276    1
# 54.219666    1
#             ..
# 57.568771    1
# 54.728457    1
# 51.888144    1
# 49.047830    1
# 52.521355    1
# Name: count, Length: 188, dtype: int64

# %% [markdown]
# # DATA VISUALIZATIONS

# %%
sns.heatmap(bi.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # TO CHECK CORRELATION

# %%
bk=bi.drop('date',axis=1)

# %%
bk
# Out:
#      temperature   humidity  windspeed       count
# 0       2.716070  45.715346  21.414957  120.000000
# 1       2.896673  54.267219  15.136882  108.000000
# 2       4.235654  45.697702  17.034578   82.000000
# 3       3.112643  50.237349  10.091568   88.000000
# 4       2.723918  49.144928  15.738204  148.000000
# ..           ...        ...        ...         ...
# 186    28.187490  63.618656  19.761499  692.000000
# 187    29.070524  61.346450  21.121738  702.333333
# 188    29.953558  59.074244  22.481976  712.666667
# 189    30.836592  56.802038  23.842215  723.000000
# 190    32.409522  52.521355  17.987135  662.000000
#
# [191 rows x 4 columns]

# %%
bkcor=bk.corr()

# %%
bkcor
# Out:
#              temperature  humidity  windspeed     count
# temperature     1.000000  0.152391  -0.058493  0.897247
# humidity        0.152391  1.000000  -0.119008  0.044918
# windspeed      -0.058493 -0.119008   1.000000 -0.130064
# count           0.897247  0.044918  -0.130064  1.000000

# %%
sns.heatmap(bkcor)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(6,4))
sns.heatmap(bkcor,cmap='tab20c',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # PLOTTING OUTLIERS

# %%
bi.columns
# Out:
# Index(['date', 'temperature', 'humidity', 'windspeed', 'count'], dtype='object')

# %%
#UNIVARIATE ANALYSIS

# %%
bk['temperature'].plot.box()
# Out:
# <Axes: >

# %%
bi['humidity'].plot.box()
# Out:
# <Axes: >

# %%
bi['windspeed'].plot.box()
# Out:
# <Axes: >

# %%
bi['count'].plot.box()
# Out:
# <Axes: >

# %%
bi.shape
# Out:
# (191, 5)

# %%
bi.plot(kind='box',subplots=True,layout=(2,2),figsize=(7,7))
# Out:
# temperature       Axes(0.125,0.53;0.352273x0.35)
# humidity       Axes(0.547727,0.53;0.352273x0.35)
# windspeed         Axes(0.125,0.11;0.352273x0.35)
# count          Axes(0.547727,0.11;0.352273x0.35)
# dtype: object

# %% [markdown]
# # TO CHECK DISTRIBUTION OF SKEWNESS

# %%
sns.distplot(bi['temperature'])
# Out:
# <Axes: xlabel='temperature', ylabel='Density'>

# %%
sns.distplot(bi['windspeed'])
# Out:
# <Axes: xlabel='windspeed', ylabel='Density'>

# %%
sns.distplot(bi['humidity'])
# Out:
# <Axes: xlabel='humidity', ylabel='Density'>

# %%
bi.plot(kind='kde',subplots=True,layout=(2,2),figsize=(10,10))
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
plt.scatter(bi['temperature'],bi['count'])

# %%
plt.scatter(bi['temperature'],bi['humidity'])

# %%
plt.scatter(bi['temperature'],bi['windspeed'])

# %%
sns.pairplot(bi)

# %% [markdown]
# # REMOVING OUTLIERS

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(bk))
z
# Out:
#      temperature  humidity  windspeed     count
# 0       1.279380  1.222633   0.557836  1.065922
# 1       1.261047  0.150672   0.688757  1.103326
# 2       1.125121  1.224845   0.311945  1.184366
# 3       1.239123  0.655808   1.690569  1.165665
# 4       1.278584  0.792741   0.569357  0.978648
# ..           ...       ...        ...       ...
# 186     1.306332  1.021514   0.229520  0.716971
# 187     1.395972  0.736697   0.499613  0.749180
# 188     1.485613  0.451880   0.769706  0.781388
# 189     1.575253  0.167063   1.039799  0.813597
# 190     1.734928  0.369512   0.122802  0.623463
#
# [191 rows x 4 columns]

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([66], dtype=int64), array([1], dtype=int64))
