# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
eda=pd.read_csv('Titanic.csv')

# %%
eda.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
eda.shape
# Out:
# (891, 12)

# %%
eda.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 eda.dtypes
#
# NameError: name 'eda' is not defined

# %%
eda.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
eda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# SUMMARY STATISTICS

# %%
eda.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# EXPLORING DATA VARIABLE

# %%
eda.SibSp.unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
eda.Parch.unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
eda.Fare.unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
eda.Parch.value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
eda.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
eda.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# Key Observation: -
#     There is 491 person in the 3rd Class,184 person in 2nd Class, 216 person in 1st Class.
#
#                 342 Person survived and 549 person died

# %% [markdown]
# DATA VISUALIZATIONS

# %%
sns.heatmap(eda.isnull())
# Out:
# <Axes: >

# %% [markdown]
# TO CHECK CORRELATION

# %%
eda_corr=eda.corr()

# %%
eda_corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(eda_corr)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.heatmap(eda_corr,cmap='Pastel1',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# PLOTING OUTLIERS

# %%
eda.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
#Univariate Analysis

# %%
eda['Survived'].plot.box()
# Out:
# <Axes: >

# %%
eda['Pclass'].plot.box()
# Out:
# <Axes: >

# %%
eda['Age'].plot.box()
# Out:
# <Axes: >

# %%
eda['Parch'].plot.box()
# Out:
# <Axes: >

# %%
eda['Fare'].plot.box()
# Out:
# <Axes: >

# %%
eda.shape
# Out:
# (891, 7)

# %%
eda.plot(kind='box',subplots=True,layout=(1,7),figsize=(10,6))
# Out:
# PassengerId       Axes(0.125,0.11;0.0945122x0.77)
# Survived       Axes(0.238415,0.11;0.0945122x0.77)
# Pclass         Axes(0.351829,0.11;0.0945122x0.77)
# Age            Axes(0.465244,0.11;0.0945122x0.77)
# SibSp          Axes(0.578659,0.11;0.0945122x0.77)
# Parch          Axes(0.692073,0.11;0.0945122x0.77)
# Fare           Axes(0.805488,0.11;0.0945122x0.77)
# dtype: object

# %% [markdown]
# TO CHECK DISTRIBUTION OF SKEWNESS

# %%
sns.distplot(eda['PassengerId'])
# Out:
# <Axes: xlabel='PassengerId', ylabel='Density'>

# %%
sns.distplot(eda['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Density'>

# %%
sns.distplot(eda['Parch'])
# Out:
# <Axes: xlabel='Parch', ylabel='Density'>

# %%
sns.distplot(eda['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
eda.plot(kind='kde',subplots=True,layout=(1,7),figsize=(14,6))
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>]], dtype=object)

# %%
#Bivariate analysis

# %%
plt.scatter(eda['Survived'],eda['Pclass'])

# %%
plt.scatter(eda['Survived'],eda['Age'])

# %%
plt.scatter(eda['Survived'],eda['Fare'])

# %%
sns.pairplot(eda)

# %% [markdown]
# REMOVING OUTLIERS

# %%
from scipy.stats import zscore
z=np.abs(zscore(eda))

# %%
z
# Out:
#      PassengerId  Survived    Pclass  Age     SibSp     Parch      Fare
# 0       1.730108  0.789272  0.827377  NaN  0.432793  0.473674  0.502445
# 1       1.726220  1.266990  1.566107  NaN  0.432793  0.473674  0.786845
# 2       1.722332  1.266990  0.827377  NaN  0.474545  0.473674  0.488854
# 3       1.718444  1.266990  1.566107  NaN  0.432793  0.473674  0.420730
# 4       1.714556  0.789272  0.827377  NaN  0.474545  0.473674  0.486337
# ..           ...       ...       ...  ...       ...       ...       ...
# 886     1.714556  0.789272  0.369365  NaN  0.474545  0.473674  0.386671
# 887     1.718444  1.266990  1.566107  NaN  0.474545  0.473674  0.044381
# 888     1.722332  0.789272  0.827377  NaN  0.432793  2.008933  0.176263
# 889     1.726220  1.266990  1.566107  NaN  0.474545  0.473674  0.044381
# 890     1.730108  0.789272  0.827377  NaN  0.474545  0.473674  0.492378
#
# [891 rows x 7 columns]

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 13,  16,  25,  27,  50,  59,  68,  71,  86,  88, 118, 119, 159,
#        164, 167, 171, 180, 182, 201, 233, 258, 261, 266, 278, 299, 311,
#        324, 341, 360, 377, 380, 386, 437, 438, 438, 480, 527, 541, 542,
#        557, 567, 610, 638, 678, 679, 683, 686, 689, 700, 716, 730, 736,
#        737, 742, 774, 779, 787, 792, 813, 824, 846, 850, 858, 863, 885],
#       dtype=int64), array([5, 4, 5, 6, 4, 4, 4, 4, 5, 6, 6, 4, 4, 4, 5, 4, 4, 4, 4, 4, 6, 4,
#        4, 4, 6, 6, 4, 6, 5, 6, 6, 4, 5, 5, 6, 4, 6, 4, 4, 6, 5, 5, 5, 5,
#        6, 4, 4, 6, 6, 6, 6, 5, 6, 6, 5, 6, 4, 4, 4, 4, 4, 4, 5, 4, 5],
#       dtype=int64))

# %%
z
# Out:
#      PassengerId  Survived    Pclass  Age     SibSp     Parch      Fare
# 0       1.730108  0.789272  0.827377  NaN  0.432793  0.473674  0.502445
# 1       1.726220  1.266990  1.566107  NaN  0.432793  0.473674  0.786845
# 2       1.722332  1.266990  0.827377  NaN  0.474545  0.473674  0.488854
# 3       1.718444  1.266990  1.566107  NaN  0.432793  0.473674  0.420730
# 4       1.714556  0.789272  0.827377  NaN  0.474545  0.473674  0.486337
# ..           ...       ...       ...  ...       ...       ...       ...
# 886     1.714556  0.789272  0.369365  NaN  0.474545  0.473674  0.386671
# 887     1.718444  1.266990  1.566107  NaN  0.474545  0.473674  0.044381
# 888     1.722332  0.789272  0.827377  NaN  0.432793  2.008933  0.176263
# 889     1.726220  1.266990  1.566107  NaN  0.474545  0.473674  0.044381
# 890     1.730108  0.789272  0.827377  NaN  0.474545  0.473674  0.492378
#
# [891 rows x 7 columns]

# %%
eda_new=eda[(z<3).all(axis=1)]

# %%
eda_new
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Age, SibSp, Parch, Fare]
# Index: []

# %%
eda.shape
# Out:
# (891, 7)

# %%
eda_new.shape
# Out:
# (0, 7)
